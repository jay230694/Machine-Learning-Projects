# %%
pip install wordcloud
# Out:
# ...
#   Using cached wordcloud-1.8.1.tar.gz (220 kB)
# ...
#   Running setup.py clean for wordcloud
# Failed to build wordcloud
# ...
#     Running setup.py install for wordcloud: started
#     Running setup.py install for wordcloud: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
# ...

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data=pd.read_csv("E://csv_files for class//GroceryStoreDataSet.csv",names=['products'],header=None)

# %%
data
# Out:
#                           products
# 0               MILK,BREAD,BISCUIT
# 1    BREAD,MILK,BISCUIT,CORNFLAKES
# 2              BREAD,TEA,BOURNVITA
# 3             JAM,MAGGI,BREAD,MILK
# 4                MAGGI,TEA,BISCUIT
# 5              BREAD,TEA,BOURNVITA
# 6             MAGGI,TEA,CORNFLAKES
# 7          MAGGI,BREAD,TEA,BISCUIT
# 8              JAM,MAGGI,BREAD,TEA
# 9                       BREAD,MILK
# 10  COFFEE,COCK,BISCUIT,CORNFLAKES
# 11  COFFEE,COCK,BISCUIT,CORNFLAKES
# 12          COFFEE,SUGER,BOURNVITA
# 13               BREAD,COFFEE,COCK
# 14             BREAD,SUGER,BISCUIT
# 15         COFFEE,SUGER,CORNFLAKES
# 16           BREAD,SUGER,BOURNVITA
# 17              BREAD,COFFEE,SUGER
# 18              BREAD,COFFEE,SUGER
# 19      TEA,MILK,COFFEE,CORNFLAKES

# %%
data.columns
# Out:
# Index(['products'], dtype='object')

# %%
data.values
# Out:
# array([['MILK,BREAD,BISCUIT'],
#        ['BREAD,MILK,BISCUIT,CORNFLAKES'],
#        ['BREAD,TEA,BOURNVITA'],
#        ['JAM,MAGGI,BREAD,MILK'],
#        ['MAGGI,TEA,BISCUIT'],
#        ['BREAD,TEA,BOURNVITA'],
#        ['MAGGI,TEA,CORNFLAKES'],
#        ['MAGGI,BREAD,TEA,BISCUIT'],
#        ['JAM,MAGGI,BREAD,TEA'],
#        ['BREAD,MILK'],
#        ['COFFEE,COCK,BISCUIT,CORNFLAKES'],
#        ['COFFEE,COCK,BISCUIT,CORNFLAKES'],
#        ['COFFEE,SUGER,BOURNVITA'],
#        ['BREAD,COFFEE,COCK'],
#        ['BREAD,SUGER,BISCUIT'],
#        ['COFFEE,SUGER,CORNFLAKES'],
#        ['BREAD,SUGER,BOURNVITA'],
#        ['BREAD,COFFEE,SUGER'],
#        ['BREAD,COFFEE,SUGER'],
#        ['TEA,MILK,COFFEE,CORNFLAKES']], dtype=object)

# %%
data = list(data["products"].apply(lambda x:x.split(',')))
data
# Out:
# [['MILK', 'BREAD', 'BISCUIT'],
#  ['BREAD', 'MILK', 'BISCUIT', 'CORNFLAKES'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['JAM', 'MAGGI', 'BREAD', 'MILK'],
#  ['MAGGI', 'TEA', 'BISCUIT'],
#  ['BREAD', 'TEA', 'BOURNVITA'],
#  ['MAGGI', 'TEA', 'CORNFLAKES'],
#  ['MAGGI', 'BREAD', 'TEA', 'BISCUIT'],
#  ['JAM', 'MAGGI', 'BREAD', 'TEA'],
#  ['BREAD', 'MILK'],
#  ['COFFEE', 'COCK', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'COCK', 'BISCUIT', 'CORNFLAKES'],
#  ['COFFEE', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'COCK'],
#  ['BREAD', 'SUGER', 'BISCUIT'],
#  ['COFFEE', 'SUGER', 'CORNFLAKES'],
#  ['BREAD', 'SUGER', 'BOURNVITA'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['BREAD', 'COFFEE', 'SUGER'],
#  ['TEA', 'MILK', 'COFFEE', 'CORNFLAKES']]

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
te = TransactionEncoder()
te_data = te.fit(data).transform(data)
df = pd.DataFrame(te_data,columns=te.columns_)
df
# Out:
#     BISCUIT  BOURNVITA  BREAD   COCK  COFFEE  CORNFLAKES    JAM  MAGGI   MILK  \
# 0      True      False   True  False   False       False  False  False   True
# 1      True      False   True  False   False        True  False  False   True
# 2     False       True   True  False   False       False  False  False  False
# 3     False      False   True  False   False       False   True   True   True
# 4      True      False  False  False   False       False  False   True  False
# 5     False       True   True  False   False       False  False  False  False
# 6     False      False  False  False   False        True  False   True  False
# 7      True      False   True  False   False       False  False   True  False
# 8     False      False   True  False   False       False   True   True  False
# 9     False      False   True  False   False       False  False  False   True
# 10     True      False  False   True    True        True  False  False  False
# ...

# %%
from mlxtend.frequent_patterns import apriori

# %%
df1 = apriori(df,min_support=0.01,use_colnames=True)
df1
# Out:
#     support                             itemsets
# 0      0.35                            (BISCUIT)
# 1      0.20                          (BOURNVITA)
# 2      0.65                              (BREAD)
# 3      0.15                               (COCK)
# 4      0.40                             (COFFEE)
# ..      ...                                  ...
# 78     0.05         (BREAD, MAGGI, BISCUIT, TEA)
# 79     0.10  (COFFEE, BISCUIT, COCK, CORNFLAKES)
# 80     0.05            (BREAD, JAM, MAGGI, MILK)
# 81     0.05             (BREAD, JAM, MAGGI, TEA)
# 82     0.05      (COFFEE, TEA, MILK, CORNFLAKES)
#
# [83 rows x 2 columns]

# %%
df1.sort_values(by="support",ascending=False)
# Out:
#     support                         itemsets
# 2      0.65                          (BREAD)
# 4      0.40                         (COFFEE)
# 0      0.35                        (BISCUIT)
# 10     0.35                            (TEA)
# 5      0.30                     (CORNFLAKES)
# ..      ...                              ...
# 55     0.05      (BISCUIT, MILK, CORNFLAKES)
# 57     0.05        (BREAD, SUGER, BOURNVITA)
# 17     0.05                 (SUGER, BISCUIT)
# 37     0.05              (MAGGI, CORNFLAKES)
# 82     0.05  (COFFEE, TEA, MILK, CORNFLAKES)
#
# [83 rows x 2 columns]

# %%
df1['length'] = df1['itemsets'].apply(lambda x:len(x))
df1
# Out:
#     support                             itemsets  length
# 0      0.35                            (BISCUIT)       1
# 1      0.20                          (BOURNVITA)       1
# 2      0.65                              (BREAD)       1
# 3      0.15                               (COCK)       1
# 4      0.40                             (COFFEE)       1
# ..      ...                                  ...     ...
# 78     0.05         (BREAD, MAGGI, BISCUIT, TEA)       4
# 79     0.10  (COFFEE, BISCUIT, COCK, CORNFLAKES)       4
# 80     0.05            (BREAD, JAM, MAGGI, MILK)       4
# 81     0.05             (BREAD, JAM, MAGGI, TEA)       4
# 82     0.05      (COFFEE, TEA, MILK, CORNFLAKES)       4
#
# [83 rows x 3 columns]

# %%
df1[(df1['length']==2) & (df1['support']>=0.05)]
# Out:
#     support               itemsets  length
# 11     0.20       (BREAD, BISCUIT)       2
# 12     0.10        (BISCUIT, COCK)       2
# 13     0.10      (COFFEE, BISCUIT)       2
# 14     0.15  (BISCUIT, CORNFLAKES)       2
# 15     0.10       (MAGGI, BISCUIT)       2
# 16     0.10        (BISCUIT, MILK)       2
# 17     0.05       (SUGER, BISCUIT)       2
# 18     0.10         (BISCUIT, TEA)       2
# 19     0.15     (BREAD, BOURNVITA)       2
# 20     0.05    (BOURNVITA, COFFEE)       2
# 21     0.10     (SUGER, BOURNVITA)       2
# 22     0.10       (BOURNVITA, TEA)       2
# 23     0.05          (BREAD, COCK)       2
# 24     0.15        (BREAD, COFFEE)       2
# 25     0.05    (BREAD, CORNFLAKES)       2
# 26     0.10           (BREAD, JAM)       2
# 27     0.15         (BREAD, MAGGI)       2
# 28     0.20          (BREAD, MILK)       2
# 29     0.20         (BREAD, SUGER)       2
# 30     0.20           (BREAD, TEA)       2
# 31     0.15         (COFFEE, COCK)       2
# ...

# %%
df1.ascending = False
df1
# Out:
#     support                             itemsets  length
# 0      0.35                            (BISCUIT)       1
# 1      0.20                          (BOURNVITA)       1
# 2      0.65                              (BREAD)       1
# 3      0.15                               (COCK)       1
# 4      0.40                             (COFFEE)       1
# ..      ...                                  ...     ...
# 78     0.05         (BREAD, MAGGI, BISCUIT, TEA)       4
# 79     0.10  (COFFEE, BISCUIT, COCK, CORNFLAKES)       4
# 80     0.05            (BREAD, JAM, MAGGI, MILK)       4
# 81     0.05             (BREAD, JAM, MAGGI, TEA)       4
# 82     0.05      (COFFEE, TEA, MILK, CORNFLAKES)       4
#
# [83 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from wordcloud import WordCloud

plt.rcParams['figure.figsize'] = (12, 5)
wordcloud = WordCloud(background_color = 'white', width = 1200,  height = 1200, max_words = 121).generate(str(df1['itemsets']))
plt.imshow(wordcloud)
plt.axis('off')
plt.title('Items',fontsize = 20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5252/721525027.py in <module>
#       2 import seaborn as sns
#       3
# ----> 4 from wordcloud import WordCloud
#       5
#       6 plt.rcParams['figure.figsize'] = (12, 5)
#
# ModuleNotFoundError: No module named 'wordcloud'
